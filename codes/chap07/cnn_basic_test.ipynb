# %%
# %run ../chap07/cnn_basic_model.ipynb
# %run ../chap05/dataset_flowers.ipynb
# %run ../chap06/dataset_office31.ipynb

# %%
fd = FlowersDataset([96, 96], [96, 96, 3])
od = Office31Dataset([96, 96], [96, 96, 3])

# %%
fm1 = CnnBasicModel('flowers_model_1', fd, [30, 10])
fm1.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.563, accuracy=0.289/0.290 (14/14 secs)
#     Epoch 4: cost=1.599, accuracy=0.246/0.210 (17/31 secs)
#     Epoch 6: cost=1.587, accuracy=0.259/0.300 (21/52 secs)
#     Epoch 8: cost=1.598, accuracy=0.246/0.260 (21/73 secs)
#     Epoch 10: cost=1.598, accuracy=0.246/0.210 (18/91 secs)
# Model flowers_model_1 train ended in 91 secs:
# Model flowers_model_1 test report: accuracy = 0.233, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [18,25,18,17,23] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [18,25,18,17,23] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [18,25,18,17,23] => 추정 dandelion : 정답 tulip => X

# %%
fm2 = CnnBasicModel('flowers_model_2', fd, 
                    [['full', {'width':30}], 
                     ['full', {'width':10}]])
fm2.use_adam = False
fm2.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.603, accuracy=0.257/0.270 (7/7 secs)
#     Epoch 4: cost=1.505, accuracy=0.343/0.340 (6/13 secs)
#     Epoch 6: cost=1.387, accuracy=0.392/0.450 (5/18 secs)
#     Epoch 8: cost=1.322, accuracy=0.410/0.360 (6/24 secs)
#     Epoch 10: cost=1.277, accuracy=0.433/0.450 (7/31 secs)
# Model flowers_model_2 train ended in 31 secs:
# Model flowers_model_2 test report: accuracy = 0.368, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [27,32,13,11,16] => 추정 dandelion : 정답 daisy => X
# 추정확률분포 [31,21,20, 5,23] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [ 0, 0,66, 0,34] => 추정 rose : 정답 rose => O

# %%
fm3 = CnnBasicModel('flowers_model_3', fd, 
               [['conv', {'ksize':5, 'chn':6}], 
                ['max', {'stride':4}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['avg', {'stride':2}]], 
               True)
fm3.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_3 train started:
#     Epoch 2: cost=1.301, accuracy=0.471/0.420 (141/141 secs)
#     Epoch 4: cost=1.013, accuracy=0.610/0.560 (139/280 secs)
#     Epoch 6: cost=0.839, accuracy=0.688/0.560 (139/419 secs)
#     Epoch 8: cost=0.717, accuracy=0.740/0.540 (137/556 secs)
#     Epoch 10: cost=0.545, accuracy=0.807/0.600 (137/693 secs)
# Model flowers_model_3 train ended in 693 secs:
# Model flowers_model_3 test report: accuracy = 0.518, (5 secs)
#
# Model flowers_model_3 Visualization
# 추정확률분포 [15,75, 7, 3, 1] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [ 0, 1,42, 5,53] => 추정 tulip : 정답 rose => X
# 추정확률분포 [ 0, 0,99, 0, 1] => 추정 rose : 정답 rose => O

# %%
fm4 = CnnBasicModel('flowers_model_4', fd, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
fm4.exec_all(epoch_count = 10, report = 2)
# Out:
# Model flowers_model_4 train started:
#     Epoch 2: cost=1.100, accuracy=0.577/0.530 (97/97 secs)
#     Epoch 4: cost=0.871, accuracy=0.679/0.610 (97/194 secs)
#     Epoch 6: cost=0.748, accuracy=0.724/0.650 (98/292 secs)
#     Epoch 8: cost=0.634, accuracy=0.762/0.680 (97/389 secs)
#     Epoch 10: cost=0.513, accuracy=0.810/0.720 (97/486 secs)
# Model flowers_model_4 train ended in 486 secs:
# Model flowers_model_4 test report: accuracy = 0.636, (4 secs)
#
# Model flowers_model_4 Visualization
# 추정확률분포 [88, 6, 1, 0, 5] => 추정 daisy : 정답 daisy => O
# 추정확률분포 [16,23,43, 0,18] => 추정 rose : 정답 dandelion => X
# 추정확률분포 [ 4,88, 4, 1, 3] => 추정 dandelion : 정답 dandelion => O

# %%
om1 = CnnBasicModel('office31_model_1', od, 
               [['conv', {'ksize':3, 'chn':6}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24}], 
                ['avg', {'stride':3}]])
om1.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_1 train started:
#     Epoch 2: cost=2.653, accuracy=0.829+0.402/0.800+0.440 (92/92 secs)
#     Epoch 4: cost=1.579, accuracy=0.892+0.631/0.740+0.500 (93/185 secs)
#     Epoch 6: cost=0.868, accuracy=0.939+0.800/0.880+0.540 (93/278 secs)
#     Epoch 8: cost=0.470, accuracy=0.954+0.897/0.850+0.510 (93/371 secs)
#     Epoch 10: cost=0.321, accuracy=0.972+0.930/0.900+0.590 (94/465 secs)
# Model office31_model_1 train ended in 465 secs:
# Model office31_model_1 test report: accuracy = 0.896+0.541, (3 secs)
#
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [75, 0,25] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 0, 0, 0, 0, 0, 0, 0,...] => 추정 punchers : 정답 scissors => X
# 추정확률분포 [ 0, 0, 1, 0, 0, 0, 0, 0,...] => 추정 punchers : 정답 phone => X
# 추정확률분포 [ 0, 0, 0,76, 0, 0, 0, 0,...] => 추정 bookcase : 정답 paper_notebook => X

# %%
om1.exec_all(epoch_count = 40, show_cnt = 0)
# Out:
# Model office31_model_1 train ended in 1829 secs:
# Model office31_model_1 test report: accuracy = 0.891+0.506, (3 secs)

# %%
om2 = CnnBasicModel('office31_model_2', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'sigmoid'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'sigmoid'}], 
                ['avg', {'stride':3}]])
om2.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_2 train started:
#     Epoch 2: cost=4.268, accuracy=0.686+0.031/0.700+0.010 (112/112 secs)
#     Epoch 4: cost=4.259, accuracy=0.686+0.036/0.610+0.010 (111/223 secs)
#     Epoch 6: cost=4.262, accuracy=0.686+0.034/0.620+0.010 (112/335 secs)
#     Epoch 8: cost=4.258, accuracy=0.686+0.035/0.670+0.020 (112/447 secs)
#     Epoch 10: cost=4.259, accuracy=0.686+0.039/0.620+0.030 (112/559 secs)
# Model office31_model_2 train ended in 559 secs:
# Model office31_model_2 test report: accuracy = 0.693+0.040, (6 secs)
#
# Model office31_model_2 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [70,11,19] => 추정 amazon : 정답 dslr => X
# 추정확률분포 [70,11,19] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [71,11,18] => 추정 amazon : 정답 dslr => X
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 mouse => X
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 tape_dispenser => X
# 추정확률분포 [ 3, 3, 3, 2, 2, 3, 4, 3,...] => 추정 monitor : 정답 desk_chair => X

# %%
om3 = CnnBasicModel('office31_model_3', od, 
               [['conv', {'ksize':3, 'chn':6, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':12, 'actfunc':'tanh'}], 
                ['max', {'stride':2}], 
                ['conv', {'ksize':3, 'chn':24, 'actfunc':'tanh'}], 
                ['avg', {'stride':3}]])
om3.exec_all(epoch_count = 10, report = 2)
# Out:
# Model office31_model_3 train started:
#     Epoch 2: cost=4.282, accuracy=0.686+0.034/0.670+0.020 (114/114 secs)
#     Epoch 4: cost=4.280, accuracy=0.686+0.034/0.590+0.060 (113/227 secs)
#     Epoch 6: cost=4.288, accuracy=0.686+0.035/0.680+0.060 (115/342 secs)
#     Epoch 8: cost=3.887, accuracy=0.680+0.165/0.610+0.290 (114/456 secs)
#     Epoch 10: cost=3.040, accuracy=0.713+0.380/0.770+0.250 (116/572 secs)
# Model office31_model_3 train ended in 572 secs:
# Model office31_model_3 test report: accuracy = 0.717+0.315, (7 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [71, 9,20] => 추정 amazon : 정답 webcam => X
# 추정확률분포 [34,13,53] => 추정 webcam : 정답 amazon => X
# 추정확률분포 [84, 6,10] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 0, 0, 1, 1, 0, 0,16,...] => 추정 desk_lamp : 정답 keyboard => X
# 추정확률분포 [ 1, 1, 0, 0, 1, 0, 1, 4,...] => 추정 file_cabinet : 정답 speaker => X
# 추정확률분포 [ 0, 1, 0, 0, 0, 1, 0, 0,...] => 추정 keyboard : 정답 letter_tray => X
