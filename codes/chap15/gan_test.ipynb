# %%
# %run ../chap15/gan.ipynb
# %run ../chap15/dataset_gan.ipynb

# %%
dset_pic_gogh = GanDatasetPicture('gogh.jpg')
dset_pic_jungsun = GanDatasetPicture('jungsun.jpg')
print(dset_pic_gogh)
print(dset_pic_jungsun)
# Out:
# pic_gogh.jpg(binary, 290+66+18)
# pic_jungsun.jpg(binary, 150+39+9)

# %%
conf_pic = {
    'seed_shape':  [16],
    'generator':   [['full', {'width':64}],
                    ['full', {'width':32*32*3, 'actfunc':'sigmoid'}]],
    'discriminor': [['full', {'width':64}],
                    ['full', {'width':1, 'actfunc':'none'}]]
}

gan_pic_gogh = Gan("gan_pic_gogh", dset_pic_gogh,
                        conf_pic, dump_structure=True)
gan_pic_gogh.exec_all(epoch_count=100, report=20)
# Out:
# 1: full, [16]=>[64] pm:16x64+64=1088
# 2: full, [64]=>[3072] pm:64x3072+3072=199680
# 3: full, (3072,)=>[64] pm:3072x64+64=196672
# 4: full, [64]=>[1] pm:64x1+1=65
# Total parameter count: 397505
# Model gan_pic_gogh train started:
#     Epoch 20: cost=0.509/0.994 acc=0.500/0.389 (9/9 secs)
#     Epoch 40: cost=0.633/0.723 acc=0.750/0.111 (8/17 secs)
#     Epoch 60: cost=0.461/1.142 acc=0.583/0.833 (8/25 secs)
#     Epoch 80: cost=0.511/1.190 acc=0.778/0.222 (7/32 secs)
#     Epoch 100: cost=0.508/0.983 acc=0.917/0.000 (8/40 secs)
# Model gan_pic_gogh train ended in 40 secs:
# Model gan_pic_gogh test report: accuracy = 0.917/0.000, (0 secs)

# %%
gan_pic_jungsun = Gan("gan_pic_jungsun", dset_pic_jungsun, conf_pic)
gan_pic_jungsun.exec_all(epoch_count=100, report=20)
# Out:
# Model gan_pic_jungsun train started:
#     Epoch 20: cost=0.576/0.851 acc=0.500/0.667 (4/4 secs)
#     Epoch 40: cost=0.415/1.312 acc=0.944/0.000 (4/8 secs)
#     Epoch 60: cost=0.608/0.947 acc=0.722/0.111 (4/12 secs)
#     Epoch 80: cost=0.107/2.557 acc=1.000/0.000 (4/16 secs)
#     Epoch 100: cost=0.682/0.753 acc=0.611/0.222 (4/20 secs)
# Model gan_pic_jungsun train ended in 20 secs:
# Model gan_pic_jungsun test report: accuracy = 0.462/0.410, (0 secs)

# %%
dset_gan_mnist_full = GanDatasetMnist('dset_gan_mnist_full', 4000)
dset_gan_mnist_68 = GanDatasetMnist('dset_gan_mnist_68', 2000, [6, 8])
dset_gan_mnist_8 = GanDatasetMnist('dset_gan_mnist_8', 1000, [8])
print(dset_gan_mnist_full)
print(dset_gan_mnist_68)
print(dset_gan_mnist_8)
# Out:
# dset_gan_mnist_full(binary, 3200+600+200)
# dset_gan_mnist_68(binary, 1600+300+100)
# dset_gan_mnist_8(binary, 800+150+50)

# %%
conf_gan_mnist = {
    'seed_shape':  [16],
    'generator':   [['full', {'width':64}],
                    ['full', {'width':784, 'actfunc':'tanh'}]],
    'discriminor': [['full', {'width':64}],
                    ['full', {'width':1, 'actfunc':'none'}]]
}

gan_mnist_68 = Gan("gan_mnist_68", dset_gan_mnist_68, conf_gan_mnist)
gan_mnist_68.exec_all(epoch_count=100, report=20)
# Out:
# Model gan_mnist_68 train started:
#     Epoch 20: cost=0.723/1.226 acc=0.185/0.970 (12/12 secs)
#     Epoch 40: cost=0.583/1.355 acc=0.160/0.880 (13/25 secs)
#     Epoch 60: cost=0.503/1.164 acc=0.920/0.120 (32/57 secs)
#     Epoch 80: cost=0.566/1.541 acc=0.940/0.020 (35/92 secs)
#     Epoch 100: cost=0.404/1.749 acc=0.805/0.150 (37/129 secs)
# Model gan_mnist_68 train ended in 129 secs:
# Model gan_mnist_68 test report: accuracy = 0.752/0.127, (0 secs)

# %%
gan_mnist_no_adam = Gan("gan_mnist_no_adam", dset_gan_mnist_8, conf_gan_mnist)
gan_mnist_no_adam.use_adam = False
gan_mnist_no_adam.exec_all(epoch_count=100, report=20)
# Out:
# Model gan_mnist_no_adam train started:
#     Epoch 20: cost=0.295/0.825 acc=1.000/0.000 (4/4 secs)
#     Epoch 40: cost=0.246/0.959 acc=1.000/0.000 (4/8 secs)
#     Epoch 60: cost=0.210/1.096 acc=1.000/0.000 (3/11 secs)
#     Epoch 80: cost=0.179/1.235 acc=1.000/0.000 (4/15 secs)
#     Epoch 100: cost=0.154/1.371 acc=1.000/0.000 (3/18 secs)
# Model gan_mnist_no_adam train ended in 18 secs:
# Model gan_mnist_no_adam test report: accuracy = 1.000/0.000, (0 secs)

# %%
gan_mnist_adam = Gan("gan_mnist_adam", dset_gan_mnist_8, conf_gan_mnist)
gan_mnist_adam.use_adam = True
gan_mnist_adam.exec_all(epoch_count=100, report=20)
# Out:
# Model gan_mnist_adam train started:
#     Epoch 20: cost=1.227/0.401 acc=0.660/0.500 (6/6 secs)
#     Epoch 40: cost=0.663/0.759 acc=0.520/0.640 (6/12 secs)
#     Epoch 60: cost=0.679/1.821 acc=0.660/0.280 (6/18 secs)
#     Epoch 80: cost=0.870/0.920 acc=0.810/0.060 (6/24 secs)
#     Epoch 100: cost=0.449/1.558 acc=1.000/0.000 (12/36 secs)
# Model gan_mnist_adam train ended in 36 secs:
# Model gan_mnist_adam test report: accuracy = 1.000/0.000, (0 secs)

# %%
gan_mnist_full = Gan("gan_mnist_full", dset_gan_mnist_full, conf_gan_mnist)
gan_mnist_full.exec_all(epoch_count=100, report=20)
# Out:
# Model gan_mnist_full train started:
#     Epoch 20: cost=0.691/1.145 acc=0.495/0.540 (23/23 secs)
#     Epoch 40: cost=0.670/1.299 acc=0.865/0.010 (68/91 secs)
#     Epoch 60: cost=0.415/1.414 acc=0.830/0.000 (72/163 secs)
#     Epoch 80: cost=0.300/2.144 acc=0.875/0.000 (75/238 secs)
#     Epoch 100: cost=0.231/2.572 acc=0.945/0.000 (77/315 secs)
# Model gan_mnist_full train ended in 315 secs:
# Model gan_mnist_full test report: accuracy = 0.934/0.000, (0 secs)
