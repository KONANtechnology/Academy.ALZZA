# %%
# %run ../chap05/mlp_model.ipynb
# %run ../chap05/dataset_chap123.ipynb
# %run ../chap05/dataset_flowers.ipynb

# %%
ad = AbaloneDataset()
am = MlpModel('abalone_model', ad, [])
am.exec_all(epoch_count=10, report=2)
# Out:
# Model abalone_model train started:
#     Epoch 2: cost=8.191, accuracy=0.733/0.711 (0/0 secs)
#     Epoch 4: cost=7.392, accuracy=0.744/0.694 (0/0 secs)
#     Epoch 6: cost=7.247, accuracy=0.747/0.737 (0/0 secs)
#     Epoch 8: cost=7.139, accuracy=0.748/0.725 (0/0 secs)
#     Epoch 10: cost=7.054, accuracy=0.751/0.746 (0/0 secs)
# Model abalone_model train ended in 0 secs:
# Model abalone_model test report: accuracy = 0.727, (0 secs)
#
# Model abalone_model Visualization
# [0.00,0.00,1.00,0.70,0.53,0.17,1.56,0.61,0.39,0.44] => 추정 12.9 : 정답 10.0
# [0.00,1.00,0.00,0.46,0.38,0.12,0.48,0.22,0.10,0.17] => 추정  8.7 : 정답  7.0
# [0.00,0.00,1.00,0.58,0.45,0.14,1.14,0.56,0.22,0.29] => 추정 11.3 : 정답  8.0

# %%
pd = PulsarDataset()
pm = MlpModel('pulsar_model', pd, [4])
pm.exec_all()
# Out:
# Model pulsar_model train ended in 2 secs:
# Model pulsar_model test report: accuracy = 0.971, (0 secs)
#
# Model pulsar_model Visualization
# [121.8, 48.0,  0.2,...] => 추정 별(확률 0.01) : 정답 별 => O
# [143.5, 46.0, -0.3,...] => 추정 별(확률 0.00) : 정답 별 => O
# [170.4, 40.9, -0.9,...] => 추정 별(확률 0.01) : 정답 별 => O

# %%
pm.visualize(5)
# Out:
# Model pulsar_model Visualization
# [ 26.8, 27.4,  6.1,...] => 추정 펄서(확률 1.00) : 정답 펄서 => O
# [143.5, 40.5, -0.2,...] => 추정 별(확률 0.00) : 정답 별 => O
# [ 99.0, 44.0,  0.4,...] => 추정 별(확률 0.02) : 정답 별 => O
# [134.6, 50.6,  0.0,...] => 추정 별(확률 0.00) : 정답 별 => O
# [130.0, 53.9,  0.4,...] => 추정 별(확률 0.17) : 정답 별 => O

# %%
sd = SteelDataset()
sm = MlpModel('steel_model', sd, [12,7])
sm.exec_all(epoch_count=50, report=10)
# Out:
# Model steel_model train started:
#     Epoch 10: cost=1.848, accuracy=0.352/0.299 (1/1 secs)
#     Epoch 20: cost=1.784, accuracy=0.352/0.299 (0/1 secs)
#     Epoch 30: cost=1.744, accuracy=0.352/0.299 (1/2 secs)
#     Epoch 40: cost=1.720, accuracy=0.352/0.299 (0/2 secs)
#     Epoch 50: cost=1.705, accuracy=0.352/0.299 (0/2 secs)
# Model steel_model train ended in 2 secs:
# Model steel_model test report: accuracy = 0.337, (0 secs)
#
# Model steel_model Visualization
# 추정확률분포 [ 9,10,17, 8, 7,18,30] => 추정 Other_Faults : 정답 Bumps => X
# 추정확률분포 [ 9,10,17, 8, 7,18,30] => 추정 Other_Faults : 정답 Dirtiness => X
# 추정확률분포 [ 9,10,17, 8, 7,18,30] => 추정 Other_Faults : 정답 Other_Faults => O

# %%
psd = PulsarSelectDataset()
psm = MlpModel('pulsar_select_model', psd, [4])
psm.exec_all()
# Out:
# Model pulsar_select_model train ended in 3 secs:
# Model pulsar_select_model test report: accuracy = 0.969, (0 secs)
#
# Model pulsar_select_model Visualization
# 추정확률분포 [44,56] => 추정 펄서 : 정답 펄서 => O
# 추정확률분포 [100, 0] => 추정 별 : 정답 별 => O
# 추정확률분포 [99, 1] => 추정 별 : 정답 별 => O

# %%
fd = FlowersDataset()
fm = MlpModel('flowers_model_1', fd, [10])
fm.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_1 train started:
#     Epoch 2: cost=1.607, accuracy=0.244/0.260 (2/2 secs)
#     Epoch 4: cost=1.604, accuracy=0.244/0.270 (2/4 secs)
#     Epoch 6: cost=1.603, accuracy=0.244/0.270 (2/6 secs)
#     Epoch 8: cost=1.601, accuracy=0.244/0.270 (2/8 secs)
#     Epoch 10: cost=1.601, accuracy=0.244/0.280 (3/11 secs)
# Model flowers_model_1 train ended in 11 secs:
# Model flowers_model_1 test report: accuracy = 0.239, (0 secs)
#
# Model flowers_model_1 Visualization
# 추정확률분포 [19,22,19,19,21] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [19,22,19,19,21] => 추정 dandelion : 정답 sunflower => X
# 추정확률분포 [19,22,19,19,21] => 추정 dandelion : 정답 rose => X

# %%
fm2 = MlpModel('flowers_model_2', fd, [30, 10])
fm2.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_2 train started:
#     Epoch 2: cost=1.475, accuracy=0.331/0.340 (6/6 secs)
#     Epoch 4: cost=1.361, accuracy=0.392/0.370 (5/11 secs)
#     Epoch 6: cost=1.300, accuracy=0.415/0.390 (6/17 secs)
#     Epoch 8: cost=1.254, accuracy=0.442/0.390 (6/23 secs)
#     Epoch 10: cost=1.218, accuracy=0.458/0.410 (5/28 secs)
# Model flowers_model_2 train ended in 28 secs:
# Model flowers_model_2 test report: accuracy = 0.391, (0 secs)
#
# Model flowers_model_2 Visualization
# 추정확률분포 [72,25, 2, 0, 1] => 추정 daisy : 정답 dandelion => X
# 추정확률분포 [29,41,11, 6,13] => 추정 dandelion : 정답 dandelion => O
# 추정확률분포 [ 3, 2,64, 1,30] => 추정 rose : 정답 rose => O

# %%
fm3 = MlpModel('flowers_model_3', fd, [256,16])
fm3.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_3 train started:
#     Epoch 2: cost=1.607, accuracy=0.243/0.260 (69/69 secs)
#     Epoch 4: cost=1.605, accuracy=0.243/0.330 (69/138 secs)
#     Epoch 6: cost=1.603, accuracy=0.243/0.270 (68/206 secs)
#     Epoch 8: cost=1.602, accuracy=0.243/0.260 (78/284 secs)
#     Epoch 10: cost=1.601, accuracy=0.243/0.280 (77/361 secs)
# Model flowers_model_3 train ended in 361 secs:
# Model flowers_model_3 test report: accuracy = 0.239, (0 secs)
#
# Model flowers_model_3 Visualization
# 추정확률분포 [19,22,19,19,21] => 추정 dandelion : 정답 sunflower => X
# 추정확률분포 [19,22,19,19,21] => 추정 dandelion : 정답 rose => X
# 추정확률분포 [19,22,19,19,21] => 추정 dandelion : 정답 tulip => X

# %%
fm4 = MlpModel('flowers_model_4', fd, [64,20,10])
fm4.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_4 train started:
#     Epoch 2: cost=1.382, accuracy=0.375/0.360 (13/13 secs)
#     Epoch 4: cost=1.273, accuracy=0.434/0.360 (16/29 secs)
#     Epoch 6: cost=1.204, accuracy=0.462/0.410 (14/43 secs)
#     Epoch 8: cost=1.145, accuracy=0.499/0.360 (13/56 secs)
#     Epoch 10: cost=1.093, accuracy=0.541/0.390 (13/69 secs)
# Model flowers_model_4 train ended in 69 secs:
# Model flowers_model_4 test report: accuracy = 0.426, (1 secs)
#
# Model flowers_model_4 Visualization
# 추정확률분포 [26,38, 4,10,22] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [ 0, 0, 7, 0,93] => 추정 tulip : 정답 tulip => O
# 추정확률분포 [ 0, 0, 5, 1,94] => 추정 tulip : 정답 sunflower => X

# %%
fm5 = MlpModel('flowers_model_5', fd, [64,32,16,8])
fm5.exec_all(epoch_count=10, report=2)
# Out:
# Model flowers_model_5 train started:
#     Epoch 2: cost=1.594, accuracy=0.283/0.300 (23/23 secs)
#     Epoch 4: cost=1.479, accuracy=0.341/0.340 (12/35 secs)
#     Epoch 6: cost=1.331, accuracy=0.406/0.390 (14/49 secs)
#     Epoch 8: cost=1.256, accuracy=0.454/0.390 (15/64 secs)
#     Epoch 10: cost=1.210, accuracy=0.479/0.490 (21/85 secs)
# Model flowers_model_5 train ended in 85 secs:
# Model flowers_model_5 test report: accuracy = 0.447, (0 secs)
#
# Model flowers_model_5 Visualization
# 추정확률분포 [21,17,29, 2,31] => 추정 tulip : 정답 daisy => X
# 추정확률분포 [18,33,10,18,22] => 추정 dandelion : 정답 tulip => X
# 추정확률분포 [38,32,16, 2,12] => 추정 daisy : 정답 daisy => O
