# %%
# %run ../chap06/adam_model.ipynb
# %run ../chap06/dataset_office31.ipynb

# %%
od = Office31Dataset()

# %%
om1 = AdamModel('office31_model_1', od, [10])
om1.exec_all(epoch_count=20, report=10)
# Out:
# Model office31_model_1 train started:
#     Epoch 10: cost=4.296, accuracy=0.685+0.035/0.790+0.040 (11/11 secs)
#     Epoch 20: cost=4.268, accuracy=0.685+0.037/0.780+0.020 (10/21 secs)
# Model office31_model_1 train ended in 21 secs:
# Model office31_model_1 test report: accuracy = 0.661+0.048, (1 secs)
#
# Model office31_model_1 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [65,15,20] => 추정 amazon : 정답 dslr => X
# [ 상품 추정결과 ]
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 ring_binder => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 pen => X
# 추정확률분포 [ 3, 3, 3, 3, 3, 3, 3, 3,...] => 추정 monitor : 정답 mouse => X

# %%
om2 = AdamModel('office31_model_2', od, [64,32,10])
om2.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_2 train started:
#     Epoch 10: cost=3.744, accuracy=0.802+0.099/0.850+0.060 (63/63 secs)
#     Epoch 20: cost=3.452, accuracy=0.845+0.151/0.840+0.080 (63/126 secs)
#     Epoch 30: cost=3.238, accuracy=0.873+0.204/0.860+0.110 (61/187 secs)
#     Epoch 40: cost=3.075, accuracy=0.883+0.231/0.900+0.120 (63/250 secs)
#     Epoch 50: cost=2.927, accuracy=0.883+0.260/0.890+0.170 (62/312 secs)
# Model office31_model_2 train ended in 312 secs:
# Model office31_model_2 test report: accuracy = 0.862+0.213, (0 secs)
#
# Model office31_model_2 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [96, 1, 3] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 1, 0, 0,22, 4,11, 7,11,...] => 추정 bookcase : 정답 tape_dispenser => X
# 추정확률분포 [ 0, 1, 4, 0, 0, 0, 0, 0,...] => 추정 keyboard : 정답 letter_tray => X
# 추정확률분포 [ 0, 1, 0, 1, 1, 3, 1, 7,...] => 추정 pen : 정답 ruler => X

# %%
om3 = AdamModel('office31_model_3', od, [64,32,10])
om2.use_adam = True
om3.exec_all(epoch_count=50, report=10, learning_rate=0.0001)
# Out:
# Model office31_model_3 train started:
#     Epoch 10: cost=3.713, accuracy=0.818+0.084/0.870+0.040 (62/62 secs)
#     Epoch 20: cost=3.322, accuracy=0.865+0.160/0.880+0.130 (61/123 secs)
#     Epoch 30: cost=3.118, accuracy=0.880+0.203/0.900+0.160 (63/186 secs)
#     Epoch 40: cost=2.948, accuracy=0.891+0.234/0.860+0.250 (61/247 secs)
#     Epoch 50: cost=2.812, accuracy=0.905+0.270/0.880+0.210 (63/310 secs)
# Model office31_model_3 train ended in 310 secs:
# Model office31_model_3 test report: accuracy = 0.878+0.246, (0 secs)
#
# Model office31_model_3 Visualization
# [ 도메인 추정결과 ]
# 추정확률분포 [99, 1, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# 추정확률분포 [100, 0, 0] => 추정 amazon : 정답 amazon => O
# [ 상품 추정결과 ]
# 추정확률분포 [ 0, 1, 1, 2, 4, 2, 2,10,...] => 추정 scissors : 정답 scissors => O
# 추정확률분포 [ 2, 1, 1,11, 6, 3, 0,10,...] => 추정 paper_notebook : 정답 printer => X
# 추정확률분포 [ 0, 0, 1, 2, 0, 1, 2, 1,...] => 추정 stapler : 정답 calculator => X
